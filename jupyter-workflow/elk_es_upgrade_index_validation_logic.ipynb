# %%
print(f"ELK Upgrade Index Validation Logic -> Validate index count for Source/Dest ES cluster")
# Out:
# ELK Upgrade Index Validation Logic -> Validate index count for Source/Dest ES cluster

# %% [markdown]
# ### Validate for the documents between two clusters via Reindex script
# * Compare indices between two clusters

# %%
from elasticsearch import Elasticsearch
import os
import json
import pandas as pd
from dotenv import load_dotenv
import warnings
warnings.filterwarnings("ignore")

# %%
''' pip install python-dotenv'''
load_dotenv() # will search for .env file in local folder and load variables
# Out:
# True

# %%
def get_headers():
    ''' Elasticsearch Header '''
    return {
            'Content-type': 'application/json', 
            'Authorization' : '{}'.format(os.getenv('BASIC_AUTH')),
            # 'Connection': 'close'
    }

# %%
def get_es_instance(host):
    es_client = Elasticsearch(hosts="{}".format(host), headers=get_headers(), timeout=5,  verify_certs=False)
    return es_client

''' Source cluster '''
es_obj_s_client = get_es_instance("http://localhost:9201")
''' Target cluster '''
es_obj_t_client = get_es_instance("http://localhost:9202")

# %%
def try_exists_index(es_client, index):
    try:
        if es_client.indices.exists(index):
            return True
        return False
            
    except Exception as e:
        # logging.error(e)
        print(e)
        pass

# %%
resp = es_obj_s_client.cluster.health()
print(json.dumps(resp, indent=2))
# Out:
# {
#   "cluster_name": "docker-cluster",
#   "status": "yellow",
#   "timed_out": false,
#   "number_of_nodes": 1,
#   "number_of_data_nodes": 1,
#   "active_primary_shards": 390,
#   "active_shards": 390,
#   "relocating_shards": 0,
#   "initializing_shards": 0,
#   "unassigned_shards": 390,
#   "delayed_unassigned_shards": 0,
#   "number_of_pending_tasks": 0,
#   "number_of_in_flight_fetch": 0,
#   "task_max_waiting_in_queue_millis": 0,
#   "active_shards_percent_as_number": 50.0
# }

# %%
df = pd.DataFrame.from_dict([resp])
df.head(10)
# Out:
#      cluster_name  status  timed_out  number_of_nodes  number_of_data_nodes  \
# 0  docker-cluster  yellow      False                1                     1
#
#    active_primary_shards  active_shards  relocating_shards  \
# 0                    390            390                  0
#
#    initializing_shards  unassigned_shards  delayed_unassigned_shards  \
# 0                    0                390                          0
#
#    number_of_pending_tasks  number_of_in_flight_fetch  \
# 0                        0                          0
#
#    task_max_waiting_in_queue_millis  active_shards_percent_as_number
# 0                                 0                             50.0

# %%
resp = es_obj_t_client.cluster.health()
print(json.dumps(resp, indent=2))
# Out:
# {
#   "cluster_name": "docker-elasticsearch",
#   "status": "green",
#   "timed_out": false,
#   "number_of_nodes": 1,
#   "number_of_data_nodes": 1,
#   "active_primary_shards": 17,
#   "active_shards": 17,
#   "relocating_shards": 0,
#   "initializing_shards": 0,
#   "unassigned_shards": 0,
#   "delayed_unassigned_shards": 0,
#   "number_of_pending_tasks": 0,
#   "number_of_in_flight_fetch": 0,
#   "task_max_waiting_in_queue_millis": 0,
#   "active_shards_percent_as_number": 100.0
# }

# %%
df = pd.DataFrame.from_dict([resp])
df.head(10)
# Out:
#            cluster_name status  timed_out  number_of_nodes  \
# 0  docker-elasticsearch  green      False                1
#
#    number_of_data_nodes  active_primary_shards  active_shards  \
# 0                     1                     17             17
#
#    relocating_shards  initializing_shards  unassigned_shards  \
# 0                  0                    0                  0
#
#    delayed_unassigned_shards  number_of_pending_tasks  \
# 0                          0                        0
#
#    number_of_in_flight_fetch  task_max_waiting_in_queue_millis  \
# 0                          0                                 0
#
#    active_shards_percent_as_number
# 0                            100.0

# %%
''' Verify if all records was uploaded to the target es cluster via the reindxing script '''
elk_reindex_investigation = True
'''' Verify and compare the number of docs between two es clusters regarding to the custom mappings'''
# elk_reindex_investigation = True
# Out:
# "' Verify and compare the number of docs between two es clusters regarding to the custom mappings"

# %%
if elk_reindex_investigation:
    query = {
            # "_source": False,
    	'query': {
           'match_all': {}
         }
    }
else:
    query ={
       "query":{
          "bool":{
             "must":[
                {
                   "range":{
                      "ADDTS":{
                         "gte": "%s" % '01/01/2022',
                         "lte": "%s" % '01/01/2024',
                         "format":"MM/dd/yyyy"
                      }
                   }
                },
                {
                   "range":{
                      "EDITTS":{
                         "gte": "%s" % '01/01/2022',
                         "lte": "%s" % '01/01/2024',
                         "format":"MM/dd/yyyy"
                      }
                   }
                }
             ]
          }
       }
}

# %%
''' extact a list of indices from the source cluster'''
source_idx_lists = es_obj_s_client.indices.get("*")
# logging.info(json.dumps(source_idx_lists, indent=2))
# logging.info(source_idx_lists)

# %%
def compare_docs_source_dest(es_client, es_t_client, source_idx_lists):
    is_not_exist_lists, different_doc, all_doc, all_docs_df = [], [], [], {}
    source_cluter, target_cluter, index_column, index_value, source_cnt, target_cnt = [], [], [], [], [], []
    for each_index in source_idx_lists:
        ''' exclude system indices in the source cluster such as .monitoring-es-7-2024.07.12'''
        if '.' not in each_index:
            res_count_source, res_count_target = 0, 0
            ''' compare each index between source cluster and target cluster'''
            is_exist = try_exists_index(es_t_client, each_index)
            # logging.info(f"validate index [{each_index}] exsits : results is {is_exist}")
            ''' check the number of count'''
            res_count_source = es_client.count(index=each_index, body=query)["count"]
            if is_exist:
                res_count_target = es_t_client.count(index=each_index, body=query)["count"]

            index_column.append(each_index)
            
            if res_count_source > res_count_target:
                differ_dict = {
                                each_index : {
                                            "source_docs" : "%s" % res_count_source,
                                            "target_docs" : "%s" % res_count_target,
                                            "count" : "Differ"
                                            }
                               }
                
                different_doc.append(differ_dict)
                all_doc.append(differ_dict)
                index_value.append(False)
            else:
                 differ_dict = {
                                each_index : {
                                            "source_docs" : "%s" % res_count_source,
                                            "target_docs" : "%s" % res_count_target,
                                            "count" : "Same"
                                            }
                               }
                 all_doc.append(differ_dict)
                 index_value.append(True)

            ''' es cluster '''
            source_cluter.append("{}:{}".format(es_client.transport.hosts[0]['host'], es_client.transport.hosts[0]['port']))
            target_cluter.append("{}:{}".format(es_t_client.transport.hosts[0]['host'], es_t_client.transport.hosts[0]['port']))
            ''' index cnt '''
            source_cnt.append(res_count_source)
            target_cnt.append(res_count_target)
                

            # print(res)
            if not is_exist:
                is_not_exist_lists.append(each_index)

    all_docs_df.update({"Index_Name" : index_column})
    all_docs_df.update({"source_cluster" : source_cluter})
    all_docs_df.update({"Source Count" : source_cnt})
    all_docs_df.update({"target_cluster" : target_cluter})
    all_docs_df.update({"Target Count" : target_cnt})
    all_docs_df.update({"Reindex Completed" : index_value})

    return all_doc, all_docs_df, different_doc, is_not_exist_lists

# %%
all_doc, all_docs_df, different_doc, is_not_exist_lists = compare_docs_source_dest(es_obj_s_client, es_obj_t_client, source_idx_lists)
# logging.info(different_doc)
print("all_doc : {}".format(json.dumps(all_doc, indent=2)))
# Out:
# all_doc : [
#   {
#     "wx_order": {
#       "source_docs": "1",
#       "target_docs": "0",
#       "count": "Differ"
#     }
#   },
#   {
#     "struts2-rest-showcase": {
#       "source_docs": "0",
#       "target_docs": "0",
#       "count": "Same"
#     }
#   },
#   {
#     "books": {
#       "source_docs": "1",
#       "target_docs": "0",
#       "count": "Differ"
#     }
#   },
#   {
#     "archive_es_del_queue_active_test": {
#       "source_docs": "0",
#       "target_docs": "0",
#       "count": "Same"
#     }
#   },
#   {
#     "jbossmq-httpil": {
#       "source_docs": "0",
#       "target_docs": "0",
#       "count": "Same"
#     }
#   },
#   {
#     "pages": {
#       "source_docs": "0",
#       "target_docs": "0",
#       "count": "Same"
#     }
#   },
#   {
#     "om_order_12092020_20_9_1": {
#       "source_docs": "8082",
#       "target_docs": "0",
#       "count": "Differ"
#     }
#   },
#   {
#     "test-index1": {
#       "source_docs": "0",
#       "target_docs": "0",
#       "count": "Same"
#     }
#   },
#   {
#     "my-index-01": {
#       "source_docs": "1",
#       "target_docs": "0",
#       "count": "Differ"
#     }
#   },
#   {
#     "test": {
#       "source_docs": "35",
#       "target_docs": "0",
#       "count": "Differ"
#     }
#   },
#   {
#     "json": {
#       "source_docs": "3",
#       "target_docs": "0",
#       "count": "Differ"
#     }
#   },
#   {
#     "es_pipeline_upload_test_wm": {
#       "source_docs": "0",
#       "target_docs": "0",
#       "count": "Same"
#     }
#   },
#   {
#     "test-index": {
#       "source_docs": "1",
#       "target_docs": "0",
#       "count": "Differ"
#     }
#   },
#   {
#     "ok": {
#       "source_docs": "1326",
#       "target_docs": "0",
#       "count": "Differ"
#     }
#   },
#   {
#     "struts2-blank": {
#       "source_docs": "0",
#       "target_docs": "0",
#       "count": "Same"
#     }
#   },
#   {
#     "portal": {
#       "source_docs": "0",
#       "target_docs": "0",
#       "count": "Same"
#     }
#   },
#   {
#     "my-index": {
#       "source_docs": "0",
#       "target_docs": "0",
#       "count": "Same"
#     }
#   },
#   {
#     "action": {
#       "source_docs": "0",
#       "target_docs": "0",
#       "count": "Same"
#     }
#   },
#   {
#     "es_pipeline_upload_test03152018_01": {
#       "source_docs": "0",
#       "target_docs": "0",
#       "count": "Same"
#     }
#   },
#   {
#     "wx-test-index": {
#       "source_docs": "0",
#       "target_docs": "0",
#       "count": "Same"
#     }
#   },
#   {
#     "es_pipeline_upload_test_om": {
#       "source_docs": "0",
#       "target_docs": "0",
#       "count": "Same"
#     }
#   }
# ]

# %% [markdown]
# ## Json to Dataframe
# #### - Sample for converting json to dataframe

# %%
''' sample '''
''' https://docs.kanaries.net/ko/topics/Pandas/pandas-add-column '''
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40]
}
 
df = pd.DataFrame(data)
df.head(10)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40

# %%
# print("all_docs_df : {}".format(json.dumps(all_docs_df, indent=2)))

# %%
from rich.markdown import Markdown
MARKDOWN = f"""
Reindex Report 
between source cluster : {es_obj_s_client} and target Cluster : {es_obj_t_client}
"""
Markdown(MARKDOWN)
# Out:
# Reindex Report between source cluster : <Elasticsearch([{'host': 'localhost', 'port': 9201}])> and target Cluster :
# <Elasticsearch([{'host': 'localhost', 'port': 9202}])>

# %%
# Define a styling function
def highlight_failed_rows(row):
    # Apply red background if 'Status' is 'Fail'
    if row['Reindex Completed'] == False:
        # return ['background-color: red; font-weight: bold'] * len(row)
        return ['background-color: red;'] * len(row)
    else:
        return [''] * len(row)

# %% [markdown]
# * Compare the index between two cluster for reindexing

# %%
''' Compare the ES indices between source cluster and target cluster '''
df = pd.DataFrame.from_dict(all_docs_df)
# df.head(100)
df = df.style.apply(highlight_failed_rows, axis=1)
df
# Out:
# <style type="text/css">
# #T_ac141_row0_col0, #T_ac141_row0_col1, #T_ac141_row0_col2, #T_ac141_row0_col3, #T_ac141_row0_col4, #T_ac141_row0_col5, #T_ac141_row2_col0, #T_ac141_row2_col1, #T_ac141_row2_col2, #T_ac141_row2_col3, #T_ac141_row2_col4, #T_ac141_row2_col5, #T_ac141_row6_col0, #T_ac141_row6_col1, #T_ac141_row6_col2, #T_ac141_row6_col3, #T_ac141_row6_col4, #T_ac141_row6_col5, #T_ac141_row8_col0, #T_ac141_row8_col1, #T_ac141_row8_col2, #T_ac141_row8_col3, #T_ac141_row8_col4, #T_ac141_row8_col5, #T_ac141_row9_col0, #T_ac141_row9_col1, #T_ac141_row9_col2, #T_ac141_row9_col3, #T_ac141_row9_col4, #T_ac141_row9_col5, #T_ac141_row10_col0, #T_ac141_row10_col1, #T_ac141_row10_col2, #T_ac141_row10_col3, #T_ac141_row10_col4, #T_ac141_row10_col5, #T_ac141_row12_col0, #T_ac141_row12_col1, #T_ac141_row12_col2, #T_ac141_row12_col3, #T_ac141_row12_col4, #T_ac141_row12_col5, #T_ac141_row13_col0, #T_ac141_row13_col1, #T_ac141_row13_col2, #T_ac141_row13_col3, #T_ac141_row13_col4, #T_ac141_row13_col5 {
#   background-color: red;
# }
# </style>
# <table id="T_ac141">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac141_level0_col0" class="col_heading level0 col0" >Index_Name</th>
#       <th id="T_ac141_level0_col1" class="col_heading level0 col1" >source_cluster</th>
#       <th id="T_ac141_level0_col2" class="col_heading level0 col2" >Source Count</th>
#       <th id="T_ac141_level0_col3" class="col_heading level0 col3" >target_cluster</th>
#       <th id="T_ac141_level0_col4" class="col_heading level0 col4" >Target Count</th>
#       <th id="T_ac141_level0_col5" class="col_heading level0 col5" >Reindex Completed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac141_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac141_row0_col0" class="data row0 col0" >wx_order</td>
#       <td id="T_ac141_row0_col1" class="data row0 col1" >localhost:9201</td>
#       <td id="T_ac141_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_ac141_row0_col3" class="data row0 col3" >localhost:9202</td>
#       <td id="T_ac141_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ac141_row0_col5" class="data row0 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ac141_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ac141_row1_col0" class="data row1 col0" >struts2-rest-showcase</td>
#       <td id="T_ac141_row1_col1" class="data row1 col1" >localhost:9201</td>
#       <td id="T_ac141_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_ac141_row1_col3" class="data row1 col3" >localhost:9202</td>
#       <td id="T_ac141_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_ac141_row1_col5" class="data row1 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ac141_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ac141_row2_col0" class="data row2 col0" >books</td>
#       <td id="T_ac141_row2_col1" class="data row2 col1" >localhost:9201</td>
#       <td id="T_ac141_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_ac141_row2_col3" class="data row2 col3" >localhost:9202</td>
#       <td id="T_ac141_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_ac141_row2_col5" class="data row2 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ac141_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ac141_row3_col0" class="data row3 col0" >archive_es_del_queue_active_test</td>
#       <td id="T_ac141_row3_col1" class="data row3 col1" >localhost:9201</td>
#       <td id="T_ac141_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_ac141_row3_col3" class="data row3 col3" >localhost:9202</td>
#       <td id="T_ac141_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_ac141_row3_col5" class="data row3 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ac141_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ac141_row4_col0" class="data row4 col0" >jbossmq-httpil</td>
#       <td id="T_ac141_row4_col1" class="data row4 col1" >localhost:9201</td>
#       <td id="T_ac141_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_ac141_row4_col3" class="data row4 col3" >localhost:9202</td>
#       <td id="T_ac141_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_ac141_row4_col5" class="data row4 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ac141_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ac141_row5_col0" class="data row5 col0" >pages</td>
#       <td id="T_ac141_row5_col1" class="data row5 col1" >localhost:9201</td>
#       <td id="T_ac141_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_ac141_row5_col3" class="data row5 col3" >localhost:9202</td>
#       <td id="T_ac141_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_ac141_row5_col5" class="data row5 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ac141_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ac141_row6_col0" class="data row6 col0" >om_order_12092020_20_9_1</td>
#       <td id="T_ac141_row6_col1" class="data row6 col1" >localhost:9201</td>
#       <td id="T_ac141_row6_col2" class="data row6 col2" >8082</td>
#       <td id="T_ac141_row6_col3" class="data row6 col3" >localhost:9202</td>
#       <td id="T_ac141_row6_col4" class="data row6 col4" >0</td>
#       <td id="T_ac141_row6_col5" class="data row6 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ac141_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ac141_row7_col0" class="data row7 col0" >test-index1</td>
#       <td id="T_ac141_row7_col1" class="data row7 col1" >localhost:9201</td>
#       <td id="T_ac141_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_ac141_row7_col3" class="data row7 col3" >localhost:9202</td>
#       <td id="T_ac141_row7_col4" class="data row7 col4" >0</td>
#       <td id="T_ac141_row7_col5" class="data row7 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ac141_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ac141_row8_col0" class="data row8 col0" >my-index-01</td>
#       <td id="T_ac141_row8_col1" class="data row8 col1" >localhost:9201</td>
#       <td id="T_ac141_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_ac141_row8_col3" class="data row8 col3" >localhost:9202</td>
#       <td id="T_ac141_row8_col4" class="data row8 col4" >0</td>
#       <td id="T_ac141_row8_col5" class="data row8 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ac141_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ac141_row9_col0" class="data row9 col0" >test</td>
#       <td id="T_ac141_row9_col1" class="data row9 col1" >localhost:9201</td>
#       <td id="T_ac141_row9_col2" class="data row9 col2" >35</td>
#       <td id="T_ac141_row9_col3" class="data row9 col3" >localhost:9202</td>
#       <td id="T_ac141_row9_col4" class="data row9 col4" >0</td>
#       <td id="T_ac141_row9_col5" class="data row9 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ac141_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ac141_row10_col0" class="data row10 col0" >json</td>
#       <td id="T_ac141_row10_col1" class="data row10 col1" >localhost:9201</td>
#       <td id="T_ac141_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_ac141_row10_col3" class="data row10 col3" >localhost:9202</td>
#       <td id="T_ac141_row10_col4" class="data row10 col4" >0</td>
#       <td id="T_ac141_row10_col5" class="data row10 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ac141_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ac141_row11_col0" class="data row11 col0" >es_pipeline_upload_test_wm</td>
#       <td id="T_ac141_row11_col1" class="data row11 col1" >localhost:9201</td>
#       <td id="T_ac141_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_ac141_row11_col3" class="data row11 col3" >localhost:9202</td>
#       <td id="T_ac141_row11_col4" class="data row11 col4" >0</td>
#       <td id="T_ac141_row11_col5" class="data row11 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ac141_level0_row12" c

# %%
# print("different_doc : {}".format(json.dumps(different_doc, indent=2)))

# %%
# print("is_not_exist_lists : {}".format(json.dumps(is_not_exist_lists, indent=2)))
